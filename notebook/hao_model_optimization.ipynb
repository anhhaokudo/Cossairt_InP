# %%
# Pandas library for the pandas dataframes
import pandas as pd
from pandas import DataFrame
import numpy as np
import scipy.stats as stats
import scipy



# Import Scikit-Learn library for decision tree models
import sklearn 

from sklearn import datasets, linear_model, metrics, tree
from sklearn.utils import resample

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import BaggingRegressor, ExtraTreesRegressor, GradientBoostingRegressor, RandomForestRegressor

from sklearn.linear_model import ElasticNet, Lasso,  RidgeCV

from sklearn.neighbors import KNeighborsRegressor

        
# Dataset splitting        
from sklearn.model_selection import train_test_split, LeaveOneOut, KFold, cross_validate, RandomizedSearchCV

# Errors
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score

from matplotlib import pyplot as plt

from tqdm import tqdm

import os
import joblib

# %%
df = pd.read_csv("hao_augmented_dataset.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 80 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    246 non-null    int64
#  1   Unnamed: 0.1                                  246 non-null    int64
#  2   Unnamed: 0.1.1                                246 non-null    int64
#  3   in_amount_mmol                                246 non-null    float64
#  4   p_amount_mmol                                 246 non-null    float64
#  5   sol_amount_ml                                 246 non-null    float64
#  6   TOP_amount_mmol                               246 non-null    float64
#  7   acid_amount_mmol                              246 non-null    float64
#  8   amine_amount_mmol                             246 non-null    float64
#  9   thiol_amount_mmol                             246 non-null    float64
#  10  zinc_amount_mmol                              246 non-null    float64
#  11  other_amount_mmol                             246 non-null    float64
#  12  total_volume_ml                               246 non-null    float64
#  13  temp_c                                        246 non-null    float64
#  14  time_min                                      246 non-null    float64
#  15  x0_chloroindium oxalate                       246 non-null    float64
#  16  x0_indium acetate                             246 non-null    float64
#  17  x0_indium bromide                             246 non-null    float64
#  18  x0_indium chloride                            246 non-null    float64
#  19  x0_indium iodide                              246 non-null    float64
#  20  x0_indium laurate                             246 non-null    float64
#  21  x0_indium myristate                           246 non-null    float64
#  22  x0_indium oxalate                             246 non-null    float64
#  23  x0_indium paltimate                           246 non-null    float64
#  24  x0_indium stearate                            246 non-null    float64
#  25  x0_indium trifluoroacetate                    246 non-null    float64
#  26  x0_indium tris(N,N-diisopropylacetamidinato)  246 non-null    float64
#  27  x1_bis(trimethylsilyl)phosphine               246 non-null    float64
#  28  x1_phosphine gas                              246 non-null    float64
#  29  x1_phosphorus trichloride                     246 non-null    float64
#  30  x1_sodium phosphide                           246 non-null    float64
#  31  x1_tris(diethylamino)phosphine                246 non-null    float64
#  32  x1_tris(dimethylamino)phosphine               246 non-null    float64
#  33  x1_tris(trimethylgermyl)phosphine             246 non-null    float64
#  34  x1_tris(trimethylsilyl)phosphine              246 non-null    float64
#  35  x1_white phosphorus                           246 non-null    float64
#  36  x2_4-ethylpyridine                            246 non-null    float64
#  37  x2_None                                       246 non-null    float64
#  38  x2_dimethylformamide                          246 non-null    float64
#  39  x2_mesitylene                                 246 non-null    float64
#  40  x2_octadecene                                 246 non-null    float64
#  41  x2_toluene                                    246 non-null    float64
#  42  x3_None                                       246 non-null    float64
#  43  x3_trioctylphosphine                          246 non-null    float64
#  44  x4_None                                       246 non-null    float64
#  45  x4_lauric acid                                246 non-null    float64
#  46  x4_myristic acid                              246 non-null    float64
#  47  x4_oleic acid                                 246 non-null    float64
#  48  x4_palmitic acid                              246 non-null    float64
#  49  x4_stearic acid                               246 non-null    float64
#  50  x5_None                                       246 non-null    float64
#  51  x5_dioctylamine                               246 non-null    float64
#  52  x5_dodecylamine                               246 non-null    float64
#  53  x5_hexadecylamine                             246 non-null    float64
#  54  x5_octylamine                                 246 non-null    float64
#  55  x5_oleylamine                                 246 non-null    float64
#  56  x6_None                                       246 non-null    float64
#  57  x6_dodecanethiol                              246 non-null    float64
#  58  x7_None                                       246 non-null    float64
#  59  x7_zinc acetate                               246 non-null    float64
#  60  x7_zinc bromide                               246 non-null    float64
#  61  x7_zinc chloride                              246 non-null    float64
#  62  x7_zinc iodide                                246 non-null    float64
#  63  x7_zinc octanoate                             246 non-null    float64
#  64  x7_zinc oleate                                246 non-null    float64
#  65  x7_zinc stearate                              246 non-null    float64
#  66  x7_zinc undecylenate                          246 non-null    float64
#  67  x8_None                                       246 non-null    float64
#  68  x8_acetic acid                                246 non-null    float64
#  69  x8_copper bromide                             246 non-null    float64
#  70  x8_dioctyl ether                              246 non-null    float64
#  71  x8_oleic acid                                 246 non-null    float64
#  72  x8_tetrabutylammonium myristate               246 non-null    float64
#  73  x8_trioctylamine                              246 non-null    float64
#  74  x8_trioctylphosphine oxide                    246 non-null    float64
#  75  x8_water                                      246 non-null    float64
#  76  x8_zinc iodide                                246 non-null    float64
#  77  diameter_nm                                   246 non-null    float64
#  78  abs_nm                                        246 non-null    float64
#  79  emission_nm                                   246 non-null    float64
# dtypes: float64(77), int64(3)
# memory usage: 153.9 KB
